# %% [markdown]
# # Analisis dan Segmentasi Developer serta Prediksi Penggunaan AI Tools
#
# Notebook ini menggunakan dataset Stack Overflow Developer Survey 2025 sebagai baseline awal. Fokus target supervised learning adalah `AI_Usage`, yaitu apakah developer menggunakan AI tools atau tidak.
#
# Pipeline utama:
# 1. Load dataset 2025.
# 2. Cek struktur kolom dan ketersediaan fitur.
# 3. Buat target `AI_Usage` dari `AISelect`.
# 4. Lakukan preprocessing tanpa memakai kolom AI sebagai fitur input.
# 5. Jalankan K-Means untuk segmentasi developer.
# 6. Latih Random Forest dan Linear SVM untuk prediksi penggunaan AI tools.
# 7. Simpan visualisasi, tabel, dan report ke folder `outputs`.

# %%
from pathlib import Path
import sys

import pandas as pd

# Root project adalah satu folder di atas folder notebooks.
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

OUTPUT_ROOT = PROJECT_ROOT / "outputs"
FIGURES_DIR = OUTPUT_ROOT / "figures"
TABLES_DIR = OUTPUT_ROOT / "tables"
REPORTS_DIR = OUTPUT_ROOT / "reports"

for folder in [FIGURES_DIR, TABLES_DIR, REPORTS_DIR]:
    folder.mkdir(parents=True, exist_ok=True)

from data_preprocessing import (
    CANDIDATE_FEATURES,
    TARGET_SOURCE_COLUMN,
    build_preprocessor,
    find_dataset_path,
    inspect_candidate_columns,
    load_survey_data,
    prepare_model_data,
)
from evaluate_models import (
    evaluate_classification_models,
    plot_cluster_distribution,
    plot_confusion_matrices,
    plot_kmeans_metrics,
    plot_model_comparison,
    save_classification_outputs,
)
from train_models import (
    run_kmeans_analysis,
    summarize_clusters,
    train_classification_models,
)

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 160)

# %% [markdown]
# ## 1. Load Dataset 2025

# %%
DATA_PATH = find_dataset_path(PROJECT_ROOT, year=2025)
print(f"Dataset digunakan: {DATA_PATH}")

df = load_survey_data(DATA_PATH)
print(f"Ukuran dataset: {df.shape[0]:,} baris x {df.shape[1]:,} kolom")
display(df.head())
# Out:
# Dataset digunakan: c:\Users\Luno\Documents\Esa Unggul\Mata Kuliah\Semester 4\ML\ProjectML\Survey\packages\archive\2025\results.csv
# Ukuran dataset: 49,191 baris x 172 kolom
#    ResponseId                      MainBranch              Age                                          EdLevel  \
# 0           1  I am a developer by profession  25-34 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1           2  I am a developer by profession  25-34 years old              Associate degree (A.A., A.S., etc.)
# 2           3  I am a developer by profession  35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           4  I am a developer by profession  35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4           5  I am a developer by profession  35-44 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment                                   EmploymentAddl  WorkExp  \
# 0                                           Employed  Caring for dependents (children, elderly, etc.)      8.0
# 1                                           Employed                                              NaN      2.0
# 2  Independent contractor, freelancer, or self-em...                                None of the above     10.0
# 3                                           Employed                                None of the above      4.0
# 4  Independent contractor, freelancer, or self-em...  Caring for dependents (children, elderly, etc.)     21.0
#
#                                      LearnCodeChoose                                          LearnCode                                        LearnCodeAI  \
# 0  Yes, I am not new to coding but am learning ne...  Online Courses or Certification (includes all ...  Yes, I learned how to use AI-enabled tools for...
# 1  Yes, I am not new to coding but am learning ne...  Online Courses or Certification (includes all ...  Yes, I learned how to use AI-enabled tools for...
# 2  Yes, I am not new to coding but am learning ne...  Online Courses or Certification (includes all ...  Yes, I learned how to use AI-enabled tools for...
# 3  Yes, I am not new to coding but am learning ne...  Other online resources (e.g. standard search, ...  Yes, I learned how to use AI-enabled tools for...
# 4  No, I am not new to coding and did not learn n...                                                NaN  Yes, I learned how to use AI-enabled tools for...
#
#                                           AILearnHow  YearsCode               DevType                   OrgSize                  ICorPM  \
# 0                AI CodeGen tools or AI-enabled apps       14.0     Developer, mobile        20 to 99 employees          People manager
# 1                AI CodeGen tools or AI-enabled apps       10.0   Developer, back-end      500 to 999 employees  Individual contributor
# 2  AI CodeGen tools or AI-enabled apps;Technical ...       12.0  Developer, front-end                       NaN                     NaN
# 3  AI CodeGen tools or AI-enabled apps;Videos (no...        5.0   Developer, back-end  10,000 or more employees  Individual contributor
# 4  Technical documentation (is generated for/by t...       22.0   Engineering manager                       NaN                     NaN
#
#                                           RemoteWork                                  PurchaseInfluence  TechEndorseIntro  TechEndorse_1  TechEndorse_2  \
# 0                                             Remote  Yes, I influenced the purchase of a substantia...              Work           10.0            7.0
# 1  Hybrid (some in-person, leans heavy to flexibi...                                                 No  Personal Project           13.0            1.0
# 2                                                NaN                                                 No              Work           12.0            2.0
# 3                                             Remote                                                 No  Personal Project            2.0           12.0
# 4                                                NaN  Yes, I endorsed a tool that was open-source an...              Work            6.0            3.0
#
#    TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  TechOppose_1  \
# 0            9.0            6.0            3.0           11.0           12.0            1.0            8.0            14.0                 NaN          15.0
# 1            2.0            9.0            4.0            3.0           12.0            5.0            7.0            14.0                 NaN          14.0
# 2            3.0            7.0            5.0           10.0           13.0            1.0            4.0            14.0                 NaN           8.0
# 3            6.0            5.0           13.0            3.0            8.0           11.0            7.0            14.0                 NaN          10.0
# 4            1.0            9.0           10.0            8.0            7.0            4.0            2.0            14.0                 NaN           7.0
#
#    TechOppose_2  TechOppose_3  TechOppose_5  TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# 0           7.0           8.0          12.0          11.0           1.0            6.0           13.0            3.0           16.0                NaN
# 1           1.0          13.0          10.0           9.0           3.0            4.0            2.0            5.0           15.0                NaN
# 2           1.0           2.0          12.0          13.0           3.0            9.0            4.0           11.0           15.0                NaN
# 3           5.0           8.0           4.0          13.0          12.0            2.0            7.0            1.0           15.0                NaN
# 4          13.0           3.0           9.0          12.0           6.0            1.0            8.0           14.0           15.0                NaN
#
#                        Industry  JobSatPoints_1  JobSatPoints_2  JobSatPoints_3  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# 0                       Fintech             3.0             1.0             4.0             9.0             5.0            10.0            12.0
# 1  Retail and Consumer Services            10.0             8.0             3.0             9.0            12.0             1.0             6.0
# 2          Software Development             9.0             6.0             7.0            11.0             8.0            12.0             1.0
# 3  Retail and Consumer Services             1.0             2.0             4.0             5.0             6.0             7.0             8.0
# 4          Software Development             9.0             4.0            11.0            13.0            14.0             8.0             6.0
#
#    JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  JobSatPoints_14  JobSatPoints_15  JobSatPoints_16 JobSatPoints_15_TEXT  \
# 0            11.0             2.0              6.0              7.0             13.0             14.0             15.0              8.0                  NaN
# 1             2.0            11.0              4.0              7.0             13.0             14.0             15.0              5.0                  NaN
# 2             5.0             2.0              4.0              3.0             13.0             14.0             15.0             10.0                  NaN
# 3             9.0            10.0             11.0             12.0             13.0             14.0             15.0              3.0                  NaN
# 4             5.0             7.0              2.0              1.0             12.0             10.0             15.0              3.0                  NaN
#
#        AIThreat                                            NewRole  ToolCountWork  ...                             AIModelsHaveWorkedWith  \
# 0  I'm not sure  I have neither consider or transitioned into a...            7.0  ...  openAI GPT (chatbot models);openAI Image gener...
# 1  I'm not sure  I have transitioned into a new career and/or i...            6.0  ...                        openAI GPT (chatbot models)
# 2            No  I have transitioned into a new career and/or i...            3.0  ...  Gemini (Flash general purpose models);openAI G...
# 3            No  I have neither consider or transitioned into a...            NaN  ...                                                NaN
# 4            No  I have neither consider or transitioned into a...            4.0  ...                        openAI GPT (chatbot models)
#
#                               AIModelsWantToWorkWith                                    AIModelsAdmired  AIModelsHaveEntry AIModelsWantEntry  \
# 0                                                NaN                                                NaN                NaN               NaN
# 1                        openAI GPT (chatbot models)                        openAI GPT (chatbot models)                NaN               NaN
# 2  Gemini (Flash general purpose models);Gemini (...  Gemini (Flash general purpose models);openAI G...                NaN               NaN
# 3                                                NaN                                                NaN                NaN               NaN
# 4                        openAI GPT (chatbot models)                        openAI GPT (chatbot models)                NaN               NaN
#
#                  SOAccount                      SOVisitFreq               SODuration                                         SOPartFreq  \
# 0                      Yes             A few times per week   Between 5 and 10 years  I have never participated in Q&A on Stack Over...
# 1  Not sure/can't remember           Multiple times per day  Between 10 and 15 years              Infrequently, less than once per year
# 2  Not sure/can't remember             A few times per week   Between 5 and 10 years              Infrequently, less than once per year
# 3                      Yes  A few times per month or weekly    Between 3 and 5 years  I have never participated in Q&A on Stack Over...
# 4                       No  A few times per month or weekly   Between 5 and 10 years              Infrequently, less than once per year
#
#                                       SO_Dev_Content SO_Actions_1 SO_Actions_16 SO_Actions_3 SO_Actions_4 SO_Actions_5 SO_Actions_6 SO_Actions_9 SO_Actions_7  \
# 0                                                NaN          1.0           NaN          6.0          2.0          3.0          7.0          8.0          9.0
# 1  Chat (people);Message Boards;Long-form article...          6.0           NaN          5.0          8.0          2.0          4.0          9.0         10.0
# 2  Chat (people);Videos;Lists of recommendations ...          3.0           NaN          4.0          5.0          1.0          2.0          7.0          9.0
# 3                               Videos;Chat (bot/AI)          1.0           NaN          4.0          5.0          6.0          7.0          8.0          9.0
# 4                                 Long-form articles          1.0           NaN          7.0          4.0          2.0          5.0         10.0          6.0
#
#   SO_Actions_10 SO_Actions_15 SO_Actions_15_TEXT          SOComm              SOFriction                                     AISelect       AISent  \
# 0          11.0          15.0                NaN         Neutral    Rarely, almost never  Yes, I use AI tools monthly or infrequently  Indifferent
# 1          11.0          15.0                NaN   Yes, somewhat  About half of the time                   Yes, I use AI tools weekly  Indifferent
# 2          11.0          15.0                NaN         Neutral  About half of the time                    Yes, I use AI tools daily    Favorable
# 3          11.0          15.0                NaN         Neutral    Rarely, almost never                   Yes, I use AI tools weekly    Favorable
# 4          12.0          15.0                NaN  No, not really    Rarely, almost never                   Yes, I use AI tools weekly    Favorable
#
#                         AIAcc                                      AIComplex                       AIToolCurrently partially AI  \
# 0  Neither trust nor distrust                  Bad at handling complex tasks  Learning about a codebase;Writing code;Search ...
# 1  Neither trust nor distrust                  Bad at handling complex tasks              Learning new concepts or technologies
# 2              Somewhat trust  Neither good or bad at handling complex tasks  Documenting code;Debugging or fixing code;Test...
# 3              Somewhat trust                  Bad at handling complex tasks                                                NaN
# 4  Neither trust nor distrust  Good, but not great at handling complex tasks  Learning about a codebase;Writing code;Debuggi...
#
#             AIToolDon't plan to use AI for this task                     AIToolPlan to partially use AI                        AIToolPlan to mostly use AI  \
# 0  Project planning;Deployment and monitoring;Lea...  Documenting code;Debugging or fixing code;Test...                                                NaN
# 1  Learning about a codebase;Project planning;Com...  Writing code;Documenting code;Debugging or fix...                                                NaN
# 2                                                NaN  Project planning;Committing and reviewing code...  Learning about a codebase;Writing code;Generat...
# 3  Project planning;Documenting code;Testing code...  Learning about a codebase;Writing code;Debuggi...  Search for answers;Generating content or synth...
# 4  Project planning;Documenting code;Testing code...               Generating content or synthetic data                                                NaN
#
#   AIToolCurrently mostly AI                                      AIFrustration AIExplain                                           AIAgents  \
# 0                       NaN  AI solutions that are almost right, but not quite        No  Yes, I use AI agents at work monthly or infreq...
# 1                       NaN  AI solutions that are almost right, but not qu...        No                            No, and I don't plan to
# 2                       NaN  AI solutions that are almost right, but not qu...        No                Yes, I use AI agents at work weekly
# 3                       NaN  AI solutions that are almost right, but not qu...        NO  Yes, I use AI agents at work monthly or infreq...
# 4                       NaN  AI solutions that are almost right, but not quite    partly                            No, and I don't plan to
#
#              AIAgentChange          AIAgent_Uses                  AgentUsesGeneral                        AIAgentImpactSomewhat agree  \
# 0  Not at all or minimally  Software engineering                               NaN  AI agents have increased my productivity.;AI a...
# 1  Not at all or minimally                   NaN                               NaN                                                NaN
# 2            Yes, somewhat  Software engineering  Multi-platform search enablement  AI agents have increased my productivity.;AI a...
# 3  Not at all or minimally  Software engineering               Language processing  AI agents have accelerated my learning about n...
# 4   Yes, to a great extent                   NaN                               NaN                                                NaN
#
#                                 AIAgentImpactNeutral                     AIAgentImpactSomewhat disagree AIAgentImpactStrongly agree  \
# 0  AI agents have helped me automate repetitive t...                                                NaN                         NaN
# 1                                                NaN                                                NaN                         NaN
# 2  AI agents have improved the quality of my code...  AI agents have improved collaboration within m...                         NaN
# 3  AI agents have increased my productivity.;AI a...  AI agents have helped me automate repetitive t...                         NaN
# 4                                                NaN                                                NaN                         NaN
#
#   AIAgentImpactStrongly disagree                           AIAgentChallengesNeutral                 AIAgentChallengesSomewhat disagree  \
# 0                            NaN  I am concerned about the accuracy of the infor...  Integrating AI agents with my existing tools a...
# 1                            NaN  It takes significant time and effort to learn ...                                                NaN
# 2                            NaN  It takes significant time and effort to learn ...  My company's IT and/or InfoSec teams have stri...
# 3                            NaN  It takes significant time and effort to learn ...                                                NaN
# 4                            NaN  Integrating AI agents with my existing tools a...                                                NaN
#
#                      AIAgentChallengesStrongly agree                    AIAgentChallengesSomewhat agree AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# 0  The cost of using certain AI agent platforms i...                                                NaN                                NaN              NaN
# 1  I am concerned about the accuracy of the infor...  Integrating AI agents with my existing tools a...                                NaN              NaN
# 2                                                NaN  I am concerned about the accuracy of the infor...                                NaN            Redis
# 3  I am concerned about the accuracy of the infor...  Integrating AI agents with my existing tools a...                                NaN              NaN
# 4  I am concerned about the accuracy of the infor...  It takes significant time and effort to learn ...                                NaN              NaN
#
#   AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite                                   AIAgentExternal  \
# 0              NaN            Vertex AI              NaN                  NaN             NaN                                           ChatGPT
# 1              NaN                  NaN              NaN                  NaN             NaN                                               NaN
# 2              NaN                  NaN              NaN                  NaN             NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 3              NaN                  NaN              NaN                  NaN             NaN                               ChatGPT;Claude Code
# 4              NaN                  NaN              NaN                  NaN             NaN                                               NaN
#
#   AIAgentExtWrite                                            AIHuman                                             AIOpen ConvertedCompYearly JobSat
# 0             NaN                    When I don’t trust AI’s answers              Troubleshooting, profiling, debugging             61256.0   10.0
# 1             NaN  When I don’t trust AI’s answers;When I want to...                          All skills. AI is a flop.            104413.0    9.0
# 2             NaN  When I don’t trust AI’s answers;When I want to...  Understand how things actually work, problem s...             53061.0    8.0
# 3             NaN  When I don’t trust AI’s answers;When I want to...                                                NaN             36197.0    6.0
# 4             NaN                    When I don’t trust AI’s answers  critical thinking, the skill to define the tas...             60000.0    7.0
#
# [5 rows x 172 columns]

# %% [markdown]
# ## 2. Cek Struktur Kolom
#
# Langkah ini penting karena struktur kolom Stack Overflow Developer Survey bisa berubah antar tahun. Fitur yang tidak tersedia tidak dipaksakan masuk ke pipeline.

# %%
columns_df = pd.DataFrame({"column": df.columns})
columns_df.to_csv(TABLES_DIR / "available_columns_2025.csv", index=False)

feature_availability = inspect_candidate_columns(df, CANDIDATE_FEATURES)
feature_availability.to_csv(TABLES_DIR / "candidate_feature_availability_2025.csv", index=False)

print("Jumlah kolom tersedia:", len(df.columns))
display(feature_availability)

if TARGET_SOURCE_COLUMN in df.columns:
    display(df[TARGET_SOURCE_COLUMN].value_counts(dropna=False).rename("count").to_frame())
else:
    ai_like_columns = [col for col in df.columns if "ai" in col.lower()]
    print(f"Kolom target {TARGET_SOURCE_COLUMN!r} tidak ditemukan.")
    print("Kolom yang mengandung teks 'AI':")
    print(ai_like_columns)
    print("Sesuaikan TARGET_SOURCE_COLUMN pada notebook atau src/data_preprocessing.py.")
# Out:
# Jumlah kolom tersedia: 172
#                      column  available
# 0                       Age       True
# 1                   Country       True
# 2                   EdLevel       True
# 3                   DevType       True
# 4                Employment       True
# 5                RemoteWork       True
# 6                 YearsCode       True
# 7              YearsCodePro      False
# 8    LanguageHaveWorkedWith       True
# 9    DatabaseHaveWorkedWith       True
# 10   PlatformHaveWorkedWith       True
# 11   WebframeHaveWorkedWith       True
# 12  ToolsTechHaveWorkedWith      False
#                                              count
# AISelect
# Yes, I use AI tools daily                    15883
# NaN                                          15471
# Yes, I use AI tools weekly                    5958
# No, and I don't plan to                       5454
# Yes, I use AI tools monthly or infrequently   4628
# No, but I plan to soon                        1797

# %% [markdown]
# ## 3. Bentuk Target dan Pilih Fitur
#
# `AI_Usage` dibuat dari `AISelect`:
# - `1`: jawaban dimulai dengan `Yes`.
# - `0`: jawaban dimulai dengan `No`.
#
# Kolom AI lain tidak digunakan sebagai fitur agar tidak terjadi data leakage.

# %%
try:
    X, y, metadata = prepare_model_data(df)
except KeyError as error:
    print(error)
    print("Daftar seluruh kolom tersedia disimpan di outputs/tables/available_columns_2025.csv")
    raise

print("Jumlah data setelah target kosong dibuang:", metadata["n_rows_after_target_drop"])
print("Fitur digunakan:")
print(metadata["available_features"])
print("Fitur kandidat yang tidak tersedia:")
print(metadata["missing_features"])
print("Distribusi target AI_Usage:")
print(metadata["target_distribution"])

target_distribution = y.value_counts().sort_index().rename_axis("AI_Usage").reset_index(name="count")
target_distribution["label"] = target_distribution["AI_Usage"].map({0: "Tidak menggunakan AI", 1: "Menggunakan AI"})
target_distribution.to_csv(TABLES_DIR / "target_distribution_2025.csv", index=False)
display(target_distribution)

X.head()
# Out:
# Jumlah data setelah target kosong dibuang: 33720
# Fitur digunakan:
# ['Age', 'Country', 'EdLevel', 'DevType', 'Employment', 'RemoteWork', 'YearsCode', 'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith']
# Fitur kandidat yang tidak tersedia:
# ['YearsCodePro', 'ToolsTechHaveWorkedWith']
# Distribusi target AI_Usage:
# {0: 7251, 1: 26469}
#    AI_Usage  count                 label
# 0         0   7251  Tidak menggunakan AI
# 1         1  26469        Menggunakan AI
#                Age      Country                                          EdLevel               DevType                                         Employment  \
# 0  25-34 years old      Ukraine  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile                                           Employed
# 1  25-34 years old  Netherlands              Associate degree (A.A., A.S., etc.)   Developer, back-end                                           Employed
# 2  35-44 years old      Ukraine     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end  Independent contractor, freelancer, or self-em...
# 3  35-44 years old      Ukraine     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end                                           Employed
# 4  35-44 years old      Ukraine  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager  Independent contractor, freelancer, or self-em...
#
#                                           RemoteWork  YearsCode                             LanguageHaveWorkedWith  \
# 0                                             Remote       14.0                   Bash/Shell (all shells);Dart;SQL
# 1  Hybrid (some in-person, leans heavy to flexibi...       10.0                                               Java
# 2                                                NaN       12.0                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                             Remote        5.0                                    Java;Kotlin;SQL
# 4                                                NaN       22.0  C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#
#                               DatabaseHaveWorkedWith                             PlatformHaveWorkedWith                     WebframeHaveWorkedWith
# 0                         Cloud Firestore;PostgreSQL  Amazon Web Services (AWS);Cloudflare;Firebase;...                                        NaN
# 1                                   Dynamodb;MongoDB  Amazon Web Services (AWS);Datadog;Docker;Homeb...                                Spring Boot
# 2                           MongoDB;MySQL;PostgreSQL                          Datadog;Firebase;npm;pnpm                      Next.js;Node.js;React
# 3                                                NaN             Amazon Web Services (AWS);Google Cloud                                Spring Boot
# 4  Elasticsearch;Microsoft SQL Server;MySQL;Oracl...  Amazon Web Services (AWS);APT;Docker;Make;Mave...  Angular;ASP.NET;ASP.NET Core;Flask;jQuery

# %% [markdown]
# ## 4. Preprocessing
#
# Preprocessing yang digunakan:
# - Missing value numerik: median.
# - Missing value kategorikal: `Unknown`.
# - `YearsCode` dan `YearsCodePro`: dikonversi ke numerik jika tersedia.
# - Kategorikal biasa: One-Hot Encoding.
# - Multi-select dengan pemisah `;`: tokenisasi biner.
# - Numerik: StandardScaler.

# %%
preprocessor, feature_groups = build_preprocessor(X)
display(pd.DataFrame({"feature_group": list(feature_groups.keys()), "columns": list(feature_groups.values())}))
# Out:
#            feature_group                                            columns
# 0       numeric_features                                        [YearsCode]
# 1   categorical_features  [Age, Country, EdLevel, DevType, Employment, R...
# 2  multi_select_features  [LanguageHaveWorkedWith, DatabaseHaveWorkedWit...

# %% [markdown]
# ## 5. K-Means Clustering
#
# K-Means digunakan untuk segmentasi developer. Nilai `k` dievaluasi dengan Elbow Method dan Silhouette Score. Untuk menjaga clustering tetap praktis pada fitur one-hot yang banyak, fitur hasil preprocessing direduksi lebih dahulu dengan TruncatedSVD.

# %%
kmeans_result = run_kmeans_analysis(X, preprocessor, k_values=range(2, 11))

kmeans_metrics = kmeans_result["metrics"]
best_k = kmeans_result["best_k"]
cluster_labels = kmeans_result["labels"]

kmeans_metrics.to_csv(TABLES_DIR / "kmeans_elbow_silhouette.csv", index=False)
plot_kmeans_metrics(kmeans_metrics, OUTPUT_ROOT)

print(f"Nilai k terpilih berdasarkan silhouette score tertinggi: {best_k}")
display(kmeans_metrics)
# Out:
# Nilai k terpilih berdasarkan silhouette score tertinggi: 2
#     k       inertia  silhouette_score
# 0   2  1.640901e+06          0.048200
# 1   3  1.613067e+06          0.004959
# 2   4  1.585755e+06          0.015395
# 3   5  1.566427e+06          0.017007
# 4   6  1.523395e+06          0.046285
# 5   7  1.531641e+06         -0.025045
# 6   8  1.490875e+06          0.033930
# 7   9  1.480808e+06          0.034155
# 8  10  1.470657e+06         -0.051364

# %%
cluster_summary = summarize_clusters(X, cluster_labels)
cluster_summary.to_csv(TABLES_DIR / "cluster_summary.csv", index=False)
plot_cluster_distribution(cluster_summary, OUTPUT_ROOT)

display(cluster_summary)
# Out:
#    Cluster  Jumlah_Data  Persentase                                        Age_Dominan                                    Country_Dominan  \
# 0        0        14885   44.142942  25-34 years old (5288); 35-44 years old (4680)...  United States of America (3231); Germany (1328...
# 1        1        18835   55.857058  25-34 years old (5667); 35-44 years old (4782)...  United States of America (3707); Germany (1604...
#
#                                      EdLevel_Dominan                                    DevType_Dominan                                 Employment_Dominan  \
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.) (...  Developer, full-stack (6078); Developer, back-...  Employed (11123); Independent contractor, free...
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.) (...  Developer, full-stack (3476); Developer, back-...  Employed (12821); Independent contractor, free...
#
#                                   RemoteWork_Dominan  YearsCode_Rata_Rata                     LanguageHaveWorkedWith_Dominan  \
# 0  Remote (4397); Hybrid (some in-person, leans h...            16.897034  JavaScript (13123); HTML/CSS (11892); TypeScri...
# 1  Remote (4269); Hybrid (some remote, leans heav...            17.442700  Python (8937); SQL (7705); JavaScript (7411); ...
#
#                       DatabaseHaveWorkedWith_Dominan                     PlatformHaveWorkedWith_Dominan                     WebframeHaveWorkedWith_Dominan
# 0  PostgreSQL (9237); MySQL (6403); SQLite (5996)...  npm (13440); Docker (11958); Pip (7290); Amazo...  Node.js (9146); React (8039); Express (3862); ...
# 1  PostgreSQL (5025); MySQL (3925); SQLite (3630)...  Docker (5210); Amazon Web Services (AWS) (3187...  React (2389); Node.js (2231); jQuery (1868); A...

# %% [markdown]
# ### Catatan Interpretasi Cluster
#
# Gunakan tabel `cluster_summary.csv` untuk BAB IV. Interpretasi dapat ditulis dengan pola berikut:
# - Cluster dengan dominasi negara/tipe developer tertentu dapat dijelaskan sebagai segmen geografis atau peran kerja tertentu.
# - Rata-rata `YearsCode` menunjukkan tingkat pengalaman coding pada cluster.
# - Bahasa, database, platform, dan web framework dominan menunjukkan profil teknologi yang sering digunakan oleh cluster tersebut.
# - Distribusi jumlah data per cluster menunjukkan apakah segmentasi relatif seimbang atau ada cluster yang sangat dominan.

# %% [markdown]
# ## 6. Random Forest dan Linear SVM
#
# Model supervised learning dilatih dengan train-test split dan `random_state=42`. Kedua model memakai preprocessing yang sama agar perbandingan performa lebih adil.

# %%
models, split_data = train_classification_models(X, y, preprocessor, test_size=0.2)

print("Ukuran data training:", split_data["X_train"].shape)
print("Ukuran data testing:", split_data["X_test"].shape)
print("Model selesai dilatih:", list(models.keys()))
# Out:
# Ukuran data training: (26976, 11)
# Ukuran data testing: (6744, 11)
# Model selesai dilatih: ['Random Forest', 'Linear SVM']

# %% [markdown]
# ## 7. Evaluasi Model Klasifikasi

# %%
classification_results = evaluate_classification_models(
    models,
    split_data["X_test"],
    split_data["y_test"],
)

comparison_df = save_classification_outputs(classification_results, OUTPUT_ROOT)
plot_confusion_matrices(classification_results, OUTPUT_ROOT)
plot_model_comparison(comparison_df, OUTPUT_ROOT)

display(comparison_df)

for model_name, result in classification_results.items():
    print("=" * 80)
    print(model_name)
    print(result["classification_report_text"])
# Out:
#            model  accuracy  precision    recall  f1_score
# 0  Random Forest  0.781880   0.833304  0.902720  0.866624
# 1     Linear SVM  0.668891   0.882912  0.666604  0.759660
# ================================================================================
# Random Forest
#                       precision    recall  f1-score   support
#
# Tidak Menggunakan AI       0.49      0.34      0.40      1450
#       Menggunakan AI       0.83      0.90      0.87      5294
#
#             accuracy                           0.78      6744
#            macro avg       0.66      0.62      0.63      6744
#         weighted avg       0.76      0.78      0.77      6744
#
# ================================================================================
# Linear SVM
#                       precision    recall  f1-score   support
#
# Tidak Menggunakan AI       0.36      0.68      0.47      1450
#       Menggunakan AI       0.88      0.67      0.76      5294
#
#             accuracy                           0.67      6744
#            macro avg       0.62      0.67      0.61      6744
#         weighted avg       0.77      0.67      0.70      6744

# %% [markdown]
# ## 8. Ringkasan untuk BAB IV
#
# Cell berikut membuat file ringkasan awal yang bisa dipakai sebagai bahan BAB IV. Angka performa akan mengikuti hasil eksekusi notebook di environment lokal.

# %%
best_model_row = comparison_df.sort_values("f1_score", ascending=False).iloc[0]

summary_text = f"""# Ringkasan Awal BAB IV

## Deskripsi Dataset
- Dataset: Stack Overflow Developer Survey 2025.
- Jumlah baris awal: {df.shape[0]:,}.
- Jumlah kolom awal: {df.shape[1]:,}.
- Jumlah data setelah target kosong dibuang: {metadata['n_rows_after_target_drop']:,}.

## Target Prediksi
- Target: AI_Usage.
- Sumber target: {metadata['target_source_col']}.
- Mapping: 1 = menggunakan AI tools, 0 = tidak menggunakan AI tools.
- Distribusi target: {metadata['target_distribution']}.

## Fitur
- Fitur digunakan: {', '.join(metadata['available_features'])}.
- Fitur kandidat yang tidak tersedia: {', '.join(metadata['missing_features']) if metadata['missing_features'] else '-'}.
- Kolom AI tidak dipakai sebagai input untuk menghindari data leakage.

## Preprocessing
- Missing value numerik diisi median.
- Missing value kategorikal diisi Unknown.
- YearsCode/YearsCodePro dikonversi ke numerik jika tersedia.
- Fitur kategorikal di-encode dengan One-Hot Encoding.
- Fitur multi-select dipisahkan berdasarkan titik koma dan diubah menjadi token biner.
- Fitur numerik di-scaling dengan StandardScaler.

## K-Means Clustering
- Rentang k diuji: 2 sampai 10.
- Nilai k terpilih berdasarkan silhouette score tertinggi: {best_k}.
- Tabel interpretasi cluster tersimpan di outputs/tables/cluster_summary.csv.
- Grafik elbow dan silhouette tersimpan di outputs/figures/kmeans_elbow_silhouette.png.

## Evaluasi Model Klasifikasi
- Model terbaik berdasarkan F1-score: {best_model_row['model']}.
- Accuracy: {best_model_row['accuracy']:.4f}.
- Precision: {best_model_row['precision']:.4f}.
- Recall: {best_model_row['recall']:.4f}.
- F1-score: {best_model_row['f1_score']:.4f}.
- Tabel perbandingan model tersimpan di outputs/tables/model_performance_comparison.csv.
"""

report_path = REPORTS_DIR / "bab_iv_ringkasan_awal.md"
report_path.write_text(summary_text, encoding="utf-8")
print(summary_text)
print(f"Ringkasan disimpan ke: {report_path}")
# Out:
# # Ringkasan Awal BAB IV
#
# ## Deskripsi Dataset
# - Dataset: Stack Overflow Developer Survey 2025.
# - Jumlah baris awal: 49,191.
# - Jumlah kolom awal: 172.
# - Jumlah data setelah target kosong dibuang: 33,720.
#
# ## Target Prediksi
# - Target: AI_Usage.
# - Sumber target: AISelect.
# - Mapping: 1 = menggunakan AI tools, 0 = tidak menggunakan AI tools.
# - Distribusi target: {0: 7251, 1: 26469}.
#
# ## Fitur
# - Fitur digunakan: Age, Country, EdLevel, DevType, Employment, RemoteWork, YearsCode, LanguageHaveWorkedWith, DatabaseHaveWorkedWith, PlatformHaveWorkedWith, WebframeHaveWorkedWith.
# - Fitur kandidat yang tidak tersedia: YearsCodePro, ToolsTechHaveWorkedWith.
# - Kolom AI tidak dipakai sebagai input untuk menghindari data leakage.
#
# ## Preprocessing
# - Missing value numerik diisi median.
# - Missing value kategorikal diisi Unknown.
# - YearsCode/YearsCodePro dikonversi ke numerik jika tersedia.
# - Fitur kategorikal di-encode dengan One-Hot Encoding.
# - Fitur multi-select dipisahkan berdasarkan titik koma dan diubah menjadi token biner.
# - Fitur numerik di-scaling dengan StandardScaler.
#
# ## K-Means Clustering
# - Rentang k diuji: 2 sampai 10.
# - Nilai k terpilih berdasarkan silhouette score tertinggi: 2.
# - Tabel interpretasi cluster tersimpan di outputs/tables/cluster_summary.csv.
# - Grafik elbow dan silhouette tersimpan di outputs/figures/kmeans_elbow_silhouette.png.
#
# ## Evaluasi Model Klasifikasi
# - Model terbaik berdasarkan F1-score: Random Forest.
# - Accuracy: 0.7819.
# - Precision: 0.8333.
# - Recall: 0.9027.
# - F1-score: 0.8666.
# - Tabel perbandingan model tersimpan di outputs/tables/model_performance_comparison.csv.
#
# Ringkasan disimpan ke: c:\Users\Luno\Documents\Esa Unggul\Mata Kuliah\Semester 4\ML\ProjectML\outputs\reports\bab_iv_ringkasan_awal.md
